# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_dataset(file_path): 
    return pd.read_csv(file_path) 
df = load_dataset("./data.csv") 
df.head(5)
# Out:
# /var/folders/c_/dyt3d3mx2fz__3h1m42pvp9c0000gn/T/ipykernel_49177/2173292695.py:2: DtypeWarning: Columns (10,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(file_path)
#    Crash ID State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# 0  20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 1  20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 2  20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 3  20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 4  20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age  \
# 0                           NaN                           NaN  ...  38
# 1                            No                            No  ...  28
# 2                           NaN                           NaN  ...  19
# ...

# %%
df.tail(5)
# Out:
#        Crash ID State  Month  Year    Dayweek   Time Crash Type  \
# 52838  19891246   NSW      1  1989  Wednesday  17:05     Single
# 52839  19895088    WA      1  1989     Monday   6:00     Single
# 52840  19895088    WA      1  1989     Monday   6:00     Single
# 52841  19895088    WA      1  1989     Monday   6:00     Single
# 52842  19896063   Tas      1  1989    Tuesday  12:40   Multiple
#
#       Bus Involvement Heavy Rigid Truck Involvement  \
# 52838             Yes                           NaN
# 52839              No                           NaN
# 52840              No                           NaN
# 52841              No                           NaN
# 52842              No                           NaN
#
#       Articulated Truck Involvement  ... Age National Remoteness Areas  \
# 52838                            No  ...   5                       NaN
# 52839                            No  ...  19                       NaN
# ...

# %%
sns.countplot(data=df, x='Crash Type')
df['Year'].value_counts()
# Out:
# Year
# 1989    2800
# 1990    2331
# 1991    2113
# 1995    2017
# 1992    1974
# 1996    1970
# 1993    1953
# 1994    1928
# 2000    1817
# 1997    1767
# 1999    1764
# 1998    1755
# 2001    1737
# 2002    1715
# 2005    1627
# 2003    1621
# 2007    1603
# 2006    1598
# 2004    1583
# 2009    1491
# 2008    1437
# 2010    1353
# 2012    1300
# 2016    1292
# 2011    1277
# 2017    1222
# 2015    1204
# 2013    1187
# 2019    1186
# 2014    1151
# 2018    1134
# 2020    1093
# 2021     843
# Name: count, dtype: int64

# %%
df['Crash Type'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([  505.,  1931., 13053., 11100.,  7680.,  5962.,  4733.,  4393.,
#          3026.,   460.]),
#  array([ -9.,   2.,  13.,  24.,  35.,  46.,  57.,  68.,  79.,  90., 101.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Age'])
# Out:
# /var/folders/c_/dyt3d3mx2fz__3h1m42pvp9c0000gn/T/ipykernel_49177/2872108529.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#            Crash ID         Month          Year           Age
# count  5.284300e+04  52843.000000  52843.000000  52843.000000
# mean   2.003021e+07      6.568685   2002.729974     39.662377
# std    9.383542e+04      3.457347      9.378570     21.806198
# min    1.989100e+07      1.000000   1989.000000     -9.000000
# 25%    1.995111e+07      4.000000   1995.000000     22.000000
# 50%    2.002144e+07      7.000000   2002.000000     34.000000
# 75%    2.010408e+07     10.000000   2010.000000     55.000000
# max    2.021801e+07     12.000000   2021.000000    101.000000

# %%
tips = sns.load_dataset('tips') 
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Scatter plot (Numerical - Numerical) for the relation between two columns
sns.scatterplot(x='Age', y='Year', hue='Crash Type', style='Bus Involvement', size='Month', data=df)
plt.show()

# %%
# Bar plot (Numerical - Categorical)
sns.barplot(x='Crash Type', y='Age', hue='Bus Involvement', data=df)
plt.show()

# %%
# Box plot (Numerical - Categorical)
sns.boxplot(x='Crash Type', y='Age', hue='Bus Involvement', data=df)
plt.show()

# %%
sns.displot(data=df, x='Year', hue='Crash Type', kde=True, multiple="stack")
plt.show()
# Out:
# /Users/siddhartha/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Pairplot 
sns.pairplot(df, hue='Crash Type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Pairplot
# ----> 2 sns.pairplot(df, hue='Crash Type')
#       3 plt.show()
#
# NameError: name 'sns' is not defined
